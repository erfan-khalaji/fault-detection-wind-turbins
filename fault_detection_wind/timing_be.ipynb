# %%
import os
import time

#data manipulation
import numpy as np
import pandas as pd

#learning methods
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression

#Splitting the data
from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

#Evaluation methods
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv("final.csv")
y = data['Gb2t_avg']
X = data.drop('Gb2t_avg', axis=1)
remove_list = ['Unnamed: 0', 'Ws_avg', 'Na_c_avg', 'Ws1_avg']
X = X.drop(remove_list, axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
reg = AdaBoostRegressor()
reg = reg.fit(X_train, y_train)
predictions = reg.predict(X_test)

# %%
number_of_datapoint = [i for i in range(0,40373)]
error = abs(y_test-predictions)
a4_dims = (16, 10)
fig, ax = plt.subplots(figsize=a4_dims)
plt.axhline(y=3, color="Yellow")
plt.axhline(y=5, color="Red")
ax = sns.lineplot(x=number_of_datapoint, y=error, estimator=None, lw=1, data=data)

# %%
number_of_datapoint = [i for i in range(0,12000)]
pred_val = predictions[15000:27000]
actual_val = y_test[15000:27000]
error = abs(actual_val-pred_val)
a4_dims = (16, 10)
fig, ax = plt.subplots(figsize=a4_dims)

plt.axhline(y=2.5, color="Yellow")
plt.axhline(y=4, color="Red")

ax = sns.lineplot(x=number_of_datapoint, y=error, estimator=None, lw=1, data=data)

# %%
output_upper = list()

counter = 0
for i in error:
    if(i>2.5):
        output_upper.append(i)
#         print(counter)
    counter += 1

# At time 22 + 15000 = 15022, it's 2.7
# output_upper

# %%
output_upper = list()

counter = 0
for i in error:
    if(i>4):
        output_upper.append(i)
#         print(counter)
    counter += 1
#

# %%
number_of_datapoint = [i for i in range(0,9785)]
pred_val = predictions[15000:24785]
actual_val = y_test[15000:24785]
fig = plt.figure(figsize=(16,10), dpi=200)
plt.plot(number_of_datapoint, pred_val, marker=".", color="red",label="prediction")
plt.plot(number_of_datapoint, actual_val, marker=".", color="green",label="actual")
plt.legend()
plt.show()

# %%
sns.kdeplot(actual_val, label="Actual Value")
sns.kdeplot(pred_val, bw=10, label="Predicted Value")
plt.legend();

# %%
number_of_datapoint = [i for i in range(0,9785)]
pred_val = predictions[15000:24785]
actual_val = y_test[15000:24785]
error = abs(actual_val-pred_val)
a4_dims = (16, 10)
fig, ax = plt.subplots(figsize=a4_dims)
plt.axhline(y=3, color="Yellow")
plt.axhline(y=5, color="Red")
ax = sns.lineplot(x=number_of_datapoint, y=error, estimator=None, lw=1, data=data)

# %%
error
# Out:
# 162077    0.373712
# 101655    1.779805
# 82706     1.319844
# 53997     0.663900
# 52770     0.710104
#             ...
# 42462     1.214926
# 142132    1.616911
# 16994     0.507446
# 40341     0.152364
# 193634    0.633388
# Name: Gb2t_avg, Length: 40373, dtype: float64

# %%
output_upper = list()

counter = 0
for i in error:
    if(i<3):
#         output_upper.append(i)
#         print(counter)
    counter += 1
# Out:
#   File "<ipython-input-62-4e9e0f589015>", line 8
#     counter += 1
#           ^
# IndentationError: expected an indented block

# %%
output_upper = list()

counter = 0
for i in error:
    if(i>5):
        output_upper.append(i)
        print(counter)
    counter += 1
# Out:
# 779
# 1213
# 1317
# 1858
# 2334
# 2704
# 5403
# 6211
# 6381
# 7575
# 7913
# 8687
# 9029

# %%
#Now for the best one

# %%
data = pd.read_csv("final.csv")
y = data['Gb2t_avg']
X = data.drop('Gb2t_avg', axis=1)
remove_list = ['Unnamed: 0', 'Ws_avg', 'Na_c_avg', 'Ws1_avg']
X = X.drop(remove_list, axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
reg = BaggingRegressor()
reg = reg.fit(X_train, y_train)
predictions = reg.predict(X_test)

# %%
number_of_datapoint = [i for i in range(0,40373)]
error = abs(y_test-predictions)
a4_dims = (16, 10)
fig, ax = plt.subplots(figsize=a4_dims)
plt.axhline(y=3, color="Yellow")
plt.axhline(y=5, color="Red")
ax = sns.lineplot(x=number_of_datapoint, y=error, estimator=None, lw=1, data=data)

# %%
number_of_datapoint = [i for i in range(0,9785)]
pred_val = predictions[15000:24785]
actual_val = y_test[15000:24785]
error = abs(actual_val-pred_val)
a4_dims = (16, 10)
fig, ax = plt.subplots(figsize=a4_dims)
plt.axhline(y=3, color="Yellow")
plt.axhline(y=5, color="Red")
ax = sns.lineplot(x=number_of_datapoint, y=error, estimator=None, lw=1, data=data)

# %%
output_upper = list()

counter = 0
for i in error:
    if(i>5):
        output_upper.append(i)
        print(counter)
    counter += 1
# Out:
# 5003
